# %%
import os
import pandas as pd
import numpy as np

# %%
os.listdir()
# Out:
# ['test.csv',
#  'attacks.csv',
#  'Project Week 2 Draft.ipynb',
#  'Project Week 2.ipynb',
#  '.ipynb_checkpoints']

# %%
# !pwd
# Out:
# /Users/joaootaviomeirellesratton/Desktop/Ironhack/Labs_mycodes/Projects/Week_2

# %%
df = pd.read_csv('/Users/joaootaviomeirellesratton/Desktop/Ironhack/Labs_mycodes/Projects/Week_2/attacks.csv', sep=(','), encoding=('latin-1'))

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
date_values = list(df['Year'].unique())

# %%
date_values
# Out:
# [2018.0,
#  2017.0,
#  nan,
#  2016.0,
#  2015.0,
#  2014.0,
#  2013.0,
#  2012.0,
#  2011.0,
#  2010.0,
#  2009.0,
#  2008.0,
#  2007.0,
#  2006.0,
#  2005.0,
#  2004.0,
#  2003.0,
#  2002.0,
#  2001.0,
#  2000.0,
#  1999.0,
#  1998.0,
#  1997.0,
#  1996.0,
#  1995.0,
#  1984.0,
#  1994.0,
#  1993.0,
#  1992.0,
#  1991.0,
#  1990.0,
#  1989.0,
#  1969.0,
#  1988.0,
#  1987.0,
#  1986.0,
#  1985.0,
#  1983.0,
#  1982.0,
#  1981.0,
#  1980.0,
#  1979.0,
#  1978.0,
#  1977.0,
#  1976.0,
#  1975.0,
#  1974.0,
#  1973.0,
#  1972.0,
#  1971.0,
#  1970.0,
#  1968.0,
#  1967.0,
#  1966.0,
#  1965.0,
#  1964.0,
#  1963.0,
#  1962.0,
#  1961.0,
#  1960.0,
#  1959.0,
#  1958.0,
#  1957.0,
#  1956.0,
#  1955.0,
#  1954.0,
#  1953.0,
#  1952.0,
#  1951.0,
#  1950.0,
#  1949.0,
#  1948.0,
#  1848.0,
#  1947.0,
#  1946.0,
#  1945.0,
#  1944.0,
#  1943.0,
#  1942.0,
#  1941.0,
#  1940.0,
#  1939.0,
#  1938.0,
#  1937.0,
#  1936.0,
#  1935.0,
#  1934.0,
#  1933.0,
#  1932.0,
#  1931.0,
#  1930.0,
# ...

# %%
# Counting nulls by row
mask = df.isnull().sum(axis=1) >= 23
mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25718     True
# 25719     True
# 25720     True
# 25721     True
# 25722     True
# Length: 25723, dtype: bool

# %%
df['quantity'] = df.isnull().mean(axis=1)

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df = df.drop(df[df.quantity >= 0.85].index)

# %%
df
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23', 'quantity'],
#       dtype='object')

# %%
df.drop_duplicates(subset=list(df.columns))
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
null_cols = df.isnull().mean()
null_cols
# Out:
# Case Number               0.000159
# Date                      0.000000
# Year                      0.000317
# Type                      0.000635
# Country                   0.007934
# Area                      0.072199
# Location                  0.085687
# Activity                  0.086322
# Name                      0.033323
# Sex                       0.089654
# Age                       0.449222
# Injury                    0.004443
# Fatal (Y/N)               0.085528
# Time                      0.532212
# Species                   0.450333
# Investigator or Source    0.002698
# pdf                       0.000000
# href formula              0.000159
# href                      0.000000
# Case Number.1             0.000000
# Case Number.2             0.000000
# original order            0.000000
# Unnamed: 22               0.999841
# Unnamed: 23               0.999683
# quantity                  0.000000
# dtype: float64

# %%
df
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
list(df['Year'].unique())
# Out:
# [2018.0,
#  2017.0,
#  nan,
#  2016.0,
#  2015.0,
#  2014.0,
#  2013.0,
#  2012.0,
#  2011.0,
#  2010.0,
#  2009.0,
#  2008.0,
#  2007.0,
#  2006.0,
#  2005.0,
#  2004.0,
#  2003.0,
#  2002.0,
#  2001.0,
#  2000.0,
#  1999.0,
#  1998.0,
#  1997.0,
#  1996.0,
#  1995.0,
#  1984.0,
#  1994.0,
#  1993.0,
#  1992.0,
#  1991.0,
#  1990.0,
#  1989.0,
#  1969.0,
#  1988.0,
#  1987.0,
#  1986.0,
#  1985.0,
#  1983.0,
#  1982.0,
#  1981.0,
#  1980.0,
#  1979.0,
#  1978.0,
#  1977.0,
#  1976.0,
#  1975.0,
#  1974.0,
#  1973.0,
#  1972.0,
#  1971.0,
#  1970.0,
#  1968.0,
#  1967.0,
#  1966.0,
#  1965.0,
#  1964.0,
#  1963.0,
#  1962.0,
#  1961.0,
#  1960.0,
#  1959.0,
#  1958.0,
#  1957.0,
#  1956.0,
#  1955.0,
#  1954.0,
#  1953.0,
#  1952.0,
#  1951.0,
#  1950.0,
#  1949.0,
#  1948.0,
#  1848.0,
#  1947.0,
#  1946.0,
#  1945.0,
#  1944.0,
#  1943.0,
#  1942.0,
#  1941.0,
#  1940.0,
#  1939.0,
#  1938.0,
#  1937.0,
#  1936.0,
#  1935.0,
#  1934.0,
#  1933.0,
#  1932.0,
#  1931.0,
#  1930.0,
# ...

# %%
df.query('Year == 77')
# Out:
#      Case Number      Date  Year        Type Country        Area Location  \
# 6175  0077.00.00  77  A.D.  77.0  Unprovoked     NaN  Ionian Sea      NaN
#
#            Activity   Name Sex   ...  \
# 6175  Sponge diving  males    M  ...
#
#                                  Investigator or Source             pdf  \
# 6175  Perils mentioned by Pliny the Elder (23 A.D. t...  77AD-Pliny.pdf
#
#                                            href formula  \
# 6175  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 6175  http://sharkattackfile.net/spreadsheets/pdf_di...    0077.00.00
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23  quantity
# 6175    0077.00.00          128.0         NaN         NaN  0.291667
#
# [1 rows x 25 columns]

# %%
df['Year'] = df['Year'].apply(lambda x: int(x) if x > 0 else 'N/A')

# %%
list(df['Year'].unique())
# Out:
# [2018,
#  2017,
#  'N/A',
#  2016,
#  2015,
#  2014,
#  2013,
#  2012,
#  2011,
#  2010,
#  2009,
#  2008,
#  2007,
#  2006,
#  2005,
#  2004,
#  2003,
#  2002,
#  2001,
#  2000,
#  1999,
#  1998,
#  1997,
#  1996,
#  1995,
#  1984,
#  1994,
#  1993,
#  1992,
#  1991,
#  1990,
#  1989,
#  1969,
#  1988,
#  1987,
#  1986,
#  1985,
#  1983,
#  1982,
#  1981,
#  1980,
#  1979,
#  1978,
#  1977,
#  1976,
#  1975,
#  1974,
#  1973,
#  1972,
#  1971,
#  1970,
#  1968,
#  1967,
#  1966,
#  1965,
#  1964,
#  1963,
#  1962,
#  1961,
#  1960,
#  1959,
#  1958,
#  1957,
#  1956,
#  1955,
#  1954,
#  1953,
#  1952,
#  1951,
#  1950,
#  1949,
#  1948,
#  1848,
#  1947,
#  1946,
#  1945,
#  1944,
#  1943,
#  1942,
#  1941,
#  1940,
#  1939,
#  1938,
#  1937,
#  1936,
#  1935,
#  1934,
#  1933,
#  1932,
#  1931,
#  1930,
#  1929,
#  1928,
#  1927,
#  1926,
#  1925,
#  1924,
#  1923,
#  1922,
#  1921,
#  1920,
#  1919,
#  1918,
#  1917,
#  1916,
#  1915,
#  1914,
#  1913,
#  1912,
#  1911,
#  1910,
# ...

# %%
df['Species '].fillna('Unknown').value_counts()
# Out:
# Unknown                                                2839
# White shark                                             163
# Shark involvement prior to death was not confirmed      105
# Invalid                                                 102
# Shark involvement not confirmed                          88
#                                                        ...
# A 2' shark was seen in the area by witnesses              1
# "grey shark"                                              1
# Wobbegongs                                                1
# Nurse shark, 6'                                           1
# 60 cm to 90 cm [2' to 3'] blacktip or spinner shark       1
# Name: Species , Length: 1549, dtype: int64

# %%
import re

# %%
df['Species_copy'] = df['Species ']

# %%
list(df['Species '].unique())
# Out:
# ['White shark',
#  nan,
#  '2 m shark',
#  'Tiger shark, 3m',
#  'Tiger shark',
#  "Lemon shark, 3'",
#  "Bull shark, 6'",
#  'Grey reef shark',
#  'Invalid incident',
#  'Tawny nurse shark, 2m',
#  'Shark involvement not confirmed',
#  'Questionable',
#  '3 m shark',
#  'White shark, 3.5 m',
#  'White shark, 2.5 m',
#  "6' shark",
#  'Juvenile bull shark',
#  'Bull shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Blacktip shark',
#  'Juvenile white shark,  2.7 to 3.2 m',
#  'Bull shark, 2 m',
#  'Possibly a wobbegong',
#  'Injury believed caused by an eel, not a shark',
#  'Galapagos shark?',
#  '2m shark',
#  'Bull shark, 3 m ',
#  'Grey reef shark. 2 m',
#  'small shark',
#  'Wobbegong shark?',
#  'Juvenile nurse shark',
#  "Nurse shark. 5'",
#  'Tiger shark, female',
#  'Some drowned but other may have been killed by blue sharks',
#  'White shark, 4.6 m',
#  'Cookiecutter shark',
#  'Wobbegong shark, 1 m',
#  'White shark, 4.5 m',
# ...

# %%
df.query('Country == USA')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'USA'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df['species_treated'] = df['species_treated'].apply(lambda x: re.sub('.*[Ww]hite.*', 'white shark', x))
df['species_treated'] = df['species_treated'].apply(lambda x: re.sub('.*[Tt]iger.*', 'tiger shark', x))
df['species_treated'] = df['species_treated'].apply(lambda x: re.sub('.*[Bb]ull.*', 'bull shark', x))
df['species_treated'] = df['species_treated'].apply(lambda x: re.sub('.*[Ll]emon.*', 'lemon shark', x))

# %%
df_known = df.loc[df['species_treated'] != 'Unknown']

# %%
df_known['species_treated'].value_counts()
# Out:
# white shark                                           667
# tiger shark                                           283
# bull shark                                            178
# Shark involvement prior to death was not confirmed    105
# Invalid                                               102
#                                                      ...
# Raggedtooth shark, 2.7 m [9']                           1
#  Tawney nurse shark, 1m                                 1
# Goblin shark                                            1
# Bronze whaler shark, 1.5 m [5']                         1
# Broadnose sevengill shark                               1
# Name: species_treated, Length: 947, dtype: int64

# %%
df['href formula'].values
# Out:
# array(['http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.18-McNeely.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.09-Denges.pdf',
#        ...,
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0003-Ocracoke_1900-1905.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0002-JulesPatterson.pdf',
#        'http://sharkattackfile.net/spreadsheets/pdf_directoryND-0001-Ceylon.pdf'],
#       dtype=object)

# %%
df['species_treated'].value_counts()
# Out:
# Unknown                                               2839
# white shark                                            667
# tiger shark                                            283
# bull shark                                             178
# Shark involvement prior to death was not confirmed     105
#                                                       ...
# Remains recovered from 3 sharks                          1
#  Grey nurse shark,  3 m [10']                            1
# Raggedtooth shark, 2.7 m [9']                            1
# Mako shark, 14'                                          1
# 1.3 to 1.6 m shark                                       1
# Name: species_treated, Length: 948, dtype: int64

# %%
df
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903   N/A  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903   N/A  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   N/A  Unprovoked                 USA
# 6300     ND.0002    1883-1889   N/A  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   N/A  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...
