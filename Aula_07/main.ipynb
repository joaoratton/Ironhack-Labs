# %% [markdown]
# # Introduction to Pandas
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# #### 1. Import Numpy and Pandas and alias them to `np` and `pd` respectively.

# %%
# your code here
import numpy as np
import pandas as pd

# %% [markdown]
# #### 2. Create a Pandas Series containing the elements of the list below.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
# your code here
lst_series = pd.Series(lst)
lst_series
# Out:
# 0     5.7
# 1    75.2
# 2    74.4
# 3    84.0
# 4    66.5
# 5    66.3
# 6    55.8
# 7    75.7
# 8    29.1
# 9    43.7
# dtype: float64

# %% [markdown]
# #### 3. Use indexing to return the third value in the Series above.
#
# *Hint: Remember that indexing begins at 0.*

# %%
# your code here
lst_series[2]
# Out:
# 74.4

# %% [markdown]
# #### 4. Create a Pandas DataFrame from the list of lists below. Each sublist should be represented as a row.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
# your code here
df_b = pd.DataFrame(b)
df_b
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# #### 5. Rename the data frame columns based on the names in the list below.

# %%
colnames = ['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5']

# %%
# your code here
df_b.columns = colnames
df_b
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# #### 6. Create a subset of this data frame that contains only the Score 1, 3, and 5 columns.

# %%
# your code here
df_b[['Score_1', 'Score_3', 'Score_5']]
# Out:
#    Score_1  Score_3  Score_5
# 0     53.1     67.5     78.4
# 1     61.3     30.8     87.6
# 2     20.6     44.2     91.8
# 3     57.4     96.1     69.5
# 4     83.6     85.4     35.9
# 5     49.0      0.1     89.1
# 6     23.3     95.0     26.9
# 7     27.6     53.8     68.5
# 8     96.6     53.4     50.1
# 9     73.7     43.2     34.7

# %% [markdown]
# #### 7. From the original data frame, calculate the average Score_3 value.

# %%
# your code here
df_b['Score_3'].mean()
# Out:
# 56.95000000000001

# %% [markdown]
# #### 8. From the original data frame, calculate the maximum Score_4 value.

# %%
# your code here
df_b['Score_4'].max()
# Out:
# 88.8

# %% [markdown]
# #### 9. From the original data frame, calculate the median Score 2 value.

# %%
# your code here
df_b['Score_2'].median()
# Out:
# 40.75

# %% [markdown]
# #### 10. Create a Pandas DataFrame from the dictionary of product orders below.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
# your code here
df_orders = pd.DataFrame(orders)
df_orders.head(2)
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20

# %% [markdown]
# #### 11. Calculate the total quantity ordered and revenue generated from these orders.

# %%
# your code here
t_quantity = df_orders['Quantity'].sum()
t_revenue = df_orders['Revenue'].sum()

print(t_quantity)
print(t_revenue)
# Out:
# 2978
# 637.0

# %% [markdown]
# #### 12. Obtain the prices of the most expensive and least expensive items ordered and print the difference.

# %%
# your code here
expensive = df_orders['UnitPrice'].max()
cheap = df_orders['UnitPrice'].min()

dif = expensive - cheap
dif
# Out:
# 11.77

# %% [markdown]
# # BONUS

# %% [markdown]
# #### 1 Create a random dataframe containing 3 columns and 10 rows.
#
# *Hint: You'll have to use a `numpy.random` method to create random observations*

# %%
# your code here
df_random = pd.DataFrame(np.random.random((10,3)))
df_random
# Out:
#           0         1         2
# 0  0.480437  0.402641  0.866984
# 1  0.090626  0.796885  0.870156
# 2  0.501334  0.558952  0.741582
# 3  0.993064  0.467538  0.676025
# 4  0.693857  0.245451  0.746681
# 5  0.094001  0.560756  0.147736
# 6  0.272339  0.762778  0.281407
# 7  0.965395  0.206847  0.909092
# 8  0.615722  0.528852  0.773659
# 9  0.671801  0.181854  0.520828

# %% [markdown]
# #### 2 Create a random dataframe containing 3 columns and 10 rows with specific column names.
#
# Use `['column1', 'column2', 'column3']` as the column names.

# %%
# your code here
column_name = ['column1', 'column2', 'column3']

df_random.columns = column_name
df_random
# Out:
#     column1   column2   column3
# 0  0.480437  0.402641  0.866984
# 1  0.090626  0.796885  0.870156
# 2  0.501334  0.558952  0.741582
# 3  0.993064  0.467538  0.676025
# 4  0.693857  0.245451  0.746681
# 5  0.094001  0.560756  0.147736
# 6  0.272339  0.762778  0.281407
# 7  0.965395  0.206847  0.909092
# 8  0.615722  0.528852  0.773659
# 9  0.671801  0.181854  0.520828

# %% [markdown]
# #### 3 Create a random dataframe containing N columns and M rows with specific column names.
#
# For this task you'll have to name the columns as `['column1', 'column2', 'column3', ...,'columnN']`. You can use a list comprehension to do that.

# %%
N = 10
M = 30

# your code here

column_name = []
[column_name.append('column'+str(i)) for i in range(N+1) if i > 0]

df = pd.DataFrame(np.random.random((M,N)), columns = column_name)
df
# Out:
#      column1   column2   column3   column4   column5   column6   column7  \
# 0   0.889673  0.464412  0.798047  0.034579  0.017100  0.358989  0.064033
# 1   0.132806  0.195327  0.972282  0.511769  0.282500  0.772007  0.174191
# 2   0.013015  0.775276  0.324002  0.523236  0.016183  0.839074  0.329838
# 3   0.323083  0.395164  0.839198  0.198962  0.894237  0.955121  0.637297
# 4   0.614165  0.652592  0.667255  0.641331  0.839869  0.203742  0.782403
# 5   0.625091  0.058307  0.676896  0.323094  0.764146  0.614814  0.020018
# 6   0.901728  0.646256  0.171273  0.512760  0.257371  0.288744  0.298644
# 7   0.717896  0.426376  0.664452  0.709711  0.714083  0.660975  0.500047
# 8   0.608536  0.039906  0.655552  0.983588  0.519644  0.820633  0.473164
# 9   0.936278  0.694605  0.984145  0.886849  0.845605  0.331738  0.088490
